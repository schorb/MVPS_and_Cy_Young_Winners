# %%
import pandas as pd

# %%
df = pd.read_csv('Pitching Stats.csv')
df.head()
# Out:
#    Season            Name     Team   W  L  SV   G  GS     IP    K/9  ...  \
# 0    1995     Greg Maddux   Braves  19  2   0  28  28  209.2   7.77  ...
# 1    2015    Zack Greinke  Dodgers  19  3   0  32  32  222.2   8.08  ...
# 2    2018    Jacob deGrom     Mets  10  9   0  32  32  217.0  11.16  ...
# 3    2000  Pedro Martinez  Red Sox  18  6   0  29  29  217.0  11.78  ...
# 4    2015    Jake Arrieta     Cubs  22  6   0  33  33  229.0   9.28  ...
#
#     ERA   FIP  WAR ERA-  FIP-    H  HR   SO  WHIP  playerid
# 0  1.63  2.26  7.9   39    52  147   8  181  0.81       104
# 1  1.66  2.76  5.4   44    73  148  14  200  0.84      1943
# 2  1.70  1.99  9.0   45    49  152  10  269  0.91     10954
# 3  1.74  2.17  9.4   35    48  128  17  284  0.74       200
# 4  1.77  2.35  7.0   45    61  150  10  236  0.86      4153
#
# [5 rows x 24 columns]

# %% [markdown]
# Eric Gagne, Dodgers Closer, won the 2003 NL Cy Young award.  However, at less than 162 IP, he did not qualify for pitching statistics and is not included in this list

# %%
cya = [('Jacob deGrom', 2018),('Blake Snell', 2018),('Max Scherzer', 2017),('Corey Kluber', 2017),('Max Scherzer', 2016),('Rick Porcello', 2016),('Jake Arrieta', 2015),('Dallas Keuchel', 2015),('Clayton Kershaw', 2014),('Corey Kluber', 2014),('Clayton Kershaw', 2013),('Max Scherzer', 2013),('R.A. Dickey', 2012),('David Price', 2012),('Clayton Kershaw', 2011),('Justin Verlander', 2011),('Roy Halladay', 2010),('Felix Hernandez', 2010),('Tim Lincecum', 2009),('Zack Greinke', 2009),('Tim Lincecum', 2008),('Cliff Lee', 2008),('Jake Peavy', 2007),('CC Sabathia', 2007),('Brandon Webb', 2006),('Johan Santana', 2006),('Chris Carpenter', 2005),('Bartolo Colon', 2005),('Roger Clemens', 2004),('Johan Santana', 2004),('Roy Halladay', 2003),('Randy Johnson', 2002),('Barry Zito', 2002),('Randy Johnson', 2001),('Roger Clemens', 2001),('Randy Johnson', 2000),('Pedro Martinez', 2000),('Randy Johnson', 1999),('Pedro Martinez', 1999),('Tom Glavine', 1998),('Roger Clemens', 1998),('Pedro Martinez', 1997),('Roger Clemens', 1997),('John Smoltz', 1996),('Pat Hentgen', 1996),('Greg Maddux', 1995),('Randy Johnson', 1995)]

# %%
df['CYA'] = 0

# %% [markdown]
# Same general function as before

# %%
for v in range(len(df)):
    #separate the cya winners
    for (i, j) in cya:
    
        #match the winners with their respective seasons
        if (i, j) == (df['Name'][v], df['Season'][v]):
            #profit
            df['CYA'][v] = 1
        else:
           pass
# Out:
# /Users/brianschor/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Proper documentation of all CYA winners, sans Eric Gagne

# %%
df[df.CYA == 1]
# Out:
#      Season              Name          Team   W   L  SV   G  GS     IP    K/9  \
# 0      1995       Greg Maddux        Braves  19   2   0  28  28  209.2   7.77
# 2      2018      Jacob deGrom          Mets  10   9   0  32  32  217.0  11.16
# 3      2000    Pedro Martinez       Red Sox  18   6   0  29  29  217.0  11.78
# 4      2015      Jake Arrieta          Cubs  22   6   0  33  33  229.0   9.28
# 5      2014   Clayton Kershaw       Dodgers  21   3   0  27  27  198.1  10.85
# 6      2013   Clayton Kershaw       Dodgers  16   9   0  33  33  236.0   8.85
# 9      2018       Blake Snell          Rays  21   5   0  31  31  180.2  11.01
# 10     1997    Pedro Martinez         Expos  17   8   0  31  31  241.1  11.37
# 11     1997     Roger Clemens     Blue Jays  21   7   0  34  34  264.0   9.95
# 12     1999    Pedro Martinez       Red Sox  23   4   0  31  29  213.1  13.20
# 16     2009      Zack Greinke        Royals  16   8   0  33  33  229.1   9.50
# 25     2017      Corey Kluber       Indians  18   4   0  29  29  203.2  11.71
# 28     2010   Felix Hernandez      Mariners  13  12   0  34  34  249.2   8.36
# 30     2011   Clayton Kershaw       Dodgers  21   5   0  33  33  233.1   9.57
# 34     2002     Randy Johnson  Diamondbacks  24   5   0  35  35  260.0  11.56
# 44     2011  Justin Verlander        Tigers  24   5   0  34  34  251.0   8.96
# 49     2010      Roy Halladay      Phillies  21  10   0  33  33  250.2   7.86
# 51     2014      Corey Kluber       Indians  18   9   0  34  34  235.2  10.27
# 56     1998       Tom Glavine        Braves  20   6   0  33  33  229.1   6.16
# 57     2009      Tim Lincecum        Giants  15   7   0  32  32  225.1  10.42
# 58     1995     Randy Johnson      Mariners  18   2   0  30  30  214.1  12.35
# 59     2015    Dallas Keuchel        Astros  20   8   0  33  33  232.0   8.38
# 60     1999     Randy Johnson  Diamondbacks  17   9   0  35  35  271.2  12.06
# 61     2001     Randy Johnson  Diamondbacks  21   6   0  35  34  249.2  13.41
# 63     2017      Max Scherzer     Nationals  16   6   0  31  31  200.2  12.02
# 69     2007        Jake Peavy        Padres  19   6   0  34  34  223.1   9.67
# 70     2008         Cliff Lee       Indians  22   3   0  31  31  223.1   6.85
# 73     2012       David Price          Rays  20   5   0  31  31  211.0   8.74
# 82     2004     Johan Santana         Twins  20   6   0  34  34  228.0  10.46
# 84     2008      Tim Lincecum        Giants  18   5   0  34  33  227.0  10.51
# 89     2000     Randy Johnson  Diamondbacks  19   7   0  35  35  248.2  12.56
# 91     1998     Roger Clemens     Blue Jays  20   6   0  33  33  234.2  10.39
# 109    2012       R.A. Dickey          Mets  20   6   0  34  33  233.2   8.86
# 113    2002        Barry Zito     Athletics  23   5   0  35  35  229.1   7.14
# 118    2006     Johan Santana         Twins  19   6   0  34  34  233.2   9.44
# 137    2005   Chris Carpenter     Cardinals  21   5   0  33  33  241.2   7.93
# 168    2013      Max Scherzer        Tigers  21   3   0  32  32  214.1  10.08
# 189    1996       John Smoltz        Braves  24   8   0  35  35  253.2   9.79
# 194    2016      Max Scherzer     Nationals  20   7   0  34  34  228.1  11.19
# 204    2004     Roger Clemens        Astros  18   4   0  33  33  214.1   9.15
# 270    2006      Brandon Webb  Diamondbacks  16   8   0  33  33  235.0   6.82
# 295    2016     Rick Porcello       Red Sox  22   4   0  33  33  223.0   7.63
# 340    2007       CC Sabathia       Indians  19   7   0  34  34  241.0   7.80
# 345    1996       Pat Hentgen     Blue Jays  20  10   0  35  35  265.2   6.00
# 362    2003      Roy Halladay     Blue Jays  22   7   0  36  36  266.0   6.90
# 530    2005     Bartolo Colon        Angels  21   8   0  33  33  222.2   6.35
# 567    2001     Roger Clemens       Yankees  20   3   0  33  33  220.1   8.70
#
#      ...   FIP   WAR  ERA- FIP-    H  HR   SO  WHIP  playerid  CYA
# 0    ...  2.26   7.9    39   52  147   8  181  0.81       104    1
# 2    ...  1.99   9.0    45   49  152  10  269  0.91     10954    1
# 3    ...  2.17   9.4    35   48  128  17  284  0.74       200    1
# 4    ...  2.35   7.0    45   61  150  10  236  0.86      4153    1
# 5    ...  1.81   8.0    51   49  139   9  239  0.86      2036    1
# 6    ...  2.39   7.3    51   64  164  11  232  0.92      2036    1
# 9    ...  2.95   4.8    46   72  112  16  221  0.97     13543    1
# 10   ...  2.39   8.5    45   57  158  16  305  0.93       200    1
# 11   ...  2.25  10.7    45   50  204   9  292  1.03       815    1
# 12   ...  1.39  11.6    42   31  160   9  313  0.92       200    1
# 16   ...  2.33   8.6    48   54  195  11  242  1.07      1943    1
# 25   ...  2.50   7.3    49   56  141  21  265  0.87      2429    1
# 28   ...  3.04   6.8    59   75  194  17  232  1.06      4772    1
# 30   ...  2.47   7.4    62   65  174  15  248  0.98      2036    1
# 34   ...  2.66   8.1    54   61  197  26  334  1.03        60    1
# 44   ...  2.99   6.5    58   74  174  24  250  0.92      8700    1
# 49   ...  3.01   6.2    61   75  231  24  219  1.04      1303    1
# 51   ...  2.35   7.1    63   62  207  14  269  1.09      2429    1
# 56   ...  3.50   4.8    59   82  202  13  157  1.20        90    1
# 57   ...  2.34   7.5    60   56  168  10  261  1.05      5705    1
# 58   ...  2.08   9.5    52   45  159  12  294  1.05        60    1
# 59   ...  2.91   5.6    64   72  185  17  216  1.02      9434    1
# 60   ...  2.76   9.5    53   59  207  30  364  1.02        60    1
# 61   ...  2.13  10.4    55   47  181  19  372  1.01        60    1
# 63   ...  2.90   6.3    57   67  126  22  268  0.90      3137    1
# 69   ...  2.84   6.7    63   65  169  13  240  1.06      1051    1
# 70   ...  2.83   6.8    59   67  214  12  170  1.11      1636    1
# 73   ...  3.05   4.3    66   75  173  16  205  1.10      3184    1
# 82   ...  2.92   6.8    56   67  156  24  265  0.92       755    1
# 84   ...  2.62   7.2    61   62  182  11  265  1.17      5705    1
# 89   ...  2.53   9.6    56   53  202  23  347  1.12        60    1
# 91   ...  2.65   8.2    57   59  169  11  271  1.10       815    1
# 109  ...  3.27   4.6    73   84  192  24  230  1.05      1245    1
# 113  ...  3.87   4.5    63   89  182  24  182  1.13       944    1
# 118  ...  3.04   6.7    62   70  186  24  245  1.00       755    1
# 137  ...  2.90   6.3    68   69  204  18  213  1.06      1292    1
# 168  ...  2.74   5.9    72   69  152  18  240  0.97      3137    1
# 189  ...  2.64   8.4    69   60  199  19  276  1.00       115    1
# 194  ...  3.24   5.6    70   78  165  31  284  0.97      3137    1
# 204  ...  3.11   5.7    68   69  169  15  218  1.16       815    1
# 270  ...  3.18   6.5    66   68  216  15  178  1.13      1692    1
# 295  ...  3.40   5.1    71   81  193  23  189  1.01      2717    1
# 340  ...  3.14   6.4    73   73  238  20  209  1.14       404    1
# 345  ...  3.94   6.0    65   81  238  20  177  1.25       145    1
# 362  ...  3.23   7.0    69   71  253  26  204  1.07      1303    1
# 530  ...  3.75   4.1    82   88  215  26  157  1.16       375    1
# 567  ...  3.29   5.6    80   74  205  19  213  1.26       815    1
#
# [47 rows x 25 columns]

# %% [markdown]
# Exporting in order to model with this data

# %%
df.to_csv('pitchers cleaned.csv')

# %% [markdown]
# Creating some visualizations

# %%
df[df.CYA == 1]['ERA'].mean()
# Out:
# 2.5157446808510637

# %%
df[df.CYA == 0]['ERA'].mean()
# Out:
# 4.032071979434448

# %%
df[df.CYA == 1]['FIP'].mean()
# Out:
# 2.768085106382979

# %%
df[df.CYA == 0]['FIP'].mean()
# Out:
# 4.1185861182519385

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10), )
plt.bar('CYA FIP', df[df.CYA == 1]['FIP'].mean())
plt.bar('FIP', df[df.CYA == 0]['FIP'].mean())
plt.bar('CYA ERA', df[df.CYA == 1]['ERA'].mean())
plt.bar('ERA', df[df.CYA == 0]['ERA'].mean())
plt.title('ERA and FIP Averages for Cy Young Winners vs. Normal Pitchers', fontsize = 15)
plt.ylabel('ERA/FIP', fontsize = 13);

# %%
# plt.figure(figsize=(10,10))
# plt.bar('CYA ERA', df[df.CYA == 1]['ERA'].mean())
# plt.bar('ERA', df[df.CYA == 0]['ERA'].mean());

# %%
plt.figure(figsize=(9,9))
plt.plot(df.groupby(df.columns[0]).mean()['ERA'])
plt.plot(df.groupby(df.columns[0]).mean()['FIP'])
plt.legend()

# %%
plt.figure(figsize=(9,9))
plt.plot(df.groupby(df.columns[0]).mean()['ERA-'])
plt.plot(df.groupby(df.columns[0]).mean()['FIP-'])
plt.legend();

# %%
plt.plot(df.groupby(df.columns[0]).mean()['IP'])
