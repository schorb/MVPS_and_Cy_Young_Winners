# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/brianschor/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
dfh = pd.read_csv('Hitters_with_OPS+.csv')
dfp = pd.read_csv('pitchers cleaned.csv').drop(columns='Unnamed: 0')

# %%
dfp.head()
# Out:
#    Season            Name     Team   W  L  SV   G  GS     IP    K/9  ...  \
# 0    1995     Greg Maddux   Braves  19  2   0  28  28  209.2   7.77  ...
# 1    2015    Zack Greinke  Dodgers  19  3   0  32  32  222.2   8.08  ...
# 2    2018    Jacob deGrom     Mets  10  9   0  32  32  217.0  11.16  ...
# 3    2000  Pedro Martinez  Red Sox  18  6   0  29  29  217.0  11.78  ...
# 4    2015    Jake Arrieta     Cubs  22  6   0  33  33  229.0   9.28  ...
#
#     FIP  WAR  ERA- FIP-    H  HR   SO  WHIP  playerid  CYA
# 0  2.26  7.9    39   52  147   8  181  0.81       104    1
# 1  2.76  5.4    44   73  148  14  200  0.84      1943    0
# 2  1.99  9.0    45   49  152  10  269  0.91     10954    1
# 3  2.17  9.4    35   48  128  17  284  0.74       200    1
# 4  2.35  7.0    45   61  150  10  236  0.86      4153    1
#
# [5 rows x 25 columns]

# %%
dfh.head()
# Out:
#    Season          Name       Team    G   AB   PA    H    R  RBI  HR  ...  \
# 0    2002   Barry Bonds     Giants  143  403  612  149  117  110  46  ...
# 1    2004   Barry Bonds     Giants  147  373  617  135  129  101  45  ...
# 2    2001   Barry Bonds     Giants  153  476  664  156  129  137  73  ...
# 3    2003   Barry Bonds     Giants  130  390  550  133  111   90  45  ...
# 4    1998  Mark McGwire  Cardinals  155  509  681  152  130  147  70  ...
#
#      OBP    SLG    OPS  wRC+   WAR  OBP+    TTO%  playerid  MVP  OPS+
# 0  0.582  0.799  1.381   244  12.7   171  47.6 %      1109    1   239
# 1  0.609  0.812  1.422   233  11.9   179  51.5 %      1109    1   245
# 2  0.515  0.863  1.379   235  12.5   152  51.7 %      1109    1   230
# 3  0.529  0.749  1.278   212  10.2   155  45.6 %      1109    1   214
# 4  0.470  0.752  1.222   205   8.5   138  56.8 %   1008559    0   194
#
# [5 rows x 24 columns]

# %%
plt.figure(figsize=(9,9))
plt.bar('MVP OPS+', dfh[dfh['MVP'] == 1]['OPS+'].mean())
plt.bar('Normal OPS+', dfh[dfh['MVP'] == 0]['OPS+'].mean())
plt.title('MVP vs. Non-MVP OPS+')
plt.savefig('OPS+ averages');

# %%
dfh.MVP.value_counts()
# Out:
# 0    3561
# 1      46
# Name: MVP, dtype: int64

# %%
dfp.CYA.value_counts()
# Out:
# 0    1945
# 1      47
# Name: CYA, dtype: int64
